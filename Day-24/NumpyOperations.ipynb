# %%
import numpy as np

# %%
a = np.random.randint(1,6, (2,3))
b = np.random.randint(6,10, (3,3))
c = np.random.randint(1,9, (3,3))

# %%
b,c
# Out:
# (array([[6, 7, 8],
#         [8, 8, 6],
#         [8, 8, 8]]),
#  array([[3, 5, 6],
#         [2, 4, 2],
#         [2, 4, 4]]))

# %% [markdown]
# ## 1. Elementwise Operations

# %% [markdown]
# ### Arithmetic Operations

# %%
# b + c
np.add(b,c)
# Out:
# array([[ 9, 12, 14],
#        [10, 12,  8],
#        [10, 12, 12]])

# %%
# b - c
np.subtract(b,c)
# Out:
# array([[3, 2, 2],
#        [6, 4, 4],
#        [6, 4, 4]])

# %%
# b * c
np.multiply(b,c)
# Out:
# array([[18, 35, 48],
#        [16, 32, 12],
#        [16, 32, 32]])

# %%
# b % c
np.mod(b,c)
# Out:
# array([[0, 2, 2],
#        [0, 0, 0],
#        [0, 0, 0]])

# %%
# a ** 2
np.pow(b, 2)
# Out:
# array([[36, 49, 64],
#        [64, 64, 36],
#        [64, 64, 64]])

# %% [markdown]
# ### Trignometric

# %%
np.sin(a)
# Out:
# array([[-0.7568025 , -0.7568025 ,  0.90929743],
#        [ 0.84147098, -0.7568025 , -0.95892427]])

# %%
cot = 1 /np.tan(b)
cot
# Out:
# array([[-3.436353  ,  1.14751542, -0.14706506],
#        [-0.14706506, -0.14706506, -3.436353  ],
#        [-0.14706506, -0.14706506, -0.14706506]])

# %% [markdown]
# ### Rounding operations

# %%
np.around(cot, 2)
# Out:
# array([[-3.44,  1.15, -0.15],
#        [-0.15, -0.15, -3.44],
#        [-0.15, -0.15, -0.15]])

# %%
np.floor(cot)
# Out:
# array([[-4.,  1., -1.],
#        [-1., -1., -4.],
#        [-1., -1., -1.]])

# %%
np.ceil(cot)
# Out:
# array([[-3.,  2., -0.],
#        [-0., -0., -3.],
#        [-0., -0., -0.]])

# %% [markdown]
# ## 2. Matrix Operations

# %%
a = np.random.randint(1,50, (2,3))
b = np.random.randint(6,100, (3,3))

# %%
# MAtrix Multiplication

# a @ b

# np.dot(a,b)

res = a.dot(b)

# %%
res.shape
# Out:
# (20, 30)

# %%
# Inverse of a matrix

deter = np.linalg.det(b)
inv = np.linalg.inv(b)

# %%
inv
# Out:
# array([[-0.00149295,  0.0447332 , -0.03610727],
#        [-0.0069671 , -0.12457838,  0.16483273],
#        [ 0.02576721,  0.07978988, -0.11755599]])

# %%
# Prove A * A^-1 = I
np.dot(b, inv).round()
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[4,2],[5,3]])
C = np.array([8,9])

# %%
A_1 = np.linalg.inv(A)
A_1
# Out:
# array([[ 1.5, -1. ],
#        [-2.5,  2. ]])

# %%
X = np.dot(C, A_1)

# %%
X
# Out:
# array([-10.5,  10. ])
