# %%
import pandas as pd

titanic_df = pd.read_csv("titanic_data.csv")

# %% [markdown]
# ## EDA
#
# #### Basic Info

# %%
titanic_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# A pandas DataFrame with **891 passenger records** and **12 features**, combining numerical and categorical data. It includes survival status, class, demographics, family info, and ticket details. Some columns like **Age, Cabin, and Embarked** have missing values, making preprocessing necessary before analysis.

# %% [markdown]
# ##### Specific Information

# %%
titanic_df[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %% [markdown]
# **Description:**
#
# * Average age of passengers is approximately 29.7 years, indicating that most passengers were relatively young.
# * Age distribution is fairly symmetric, as the mean (29.7) and median (28.0) are close.
# * The minimum age is 0.42 years (about 5 months), and the oldest passenger is 80 years old.
# * There are missing values in the Age column (714 entries vs. 891 for Fare), suggesting some age data is not available.
#
# * For Fare, the mean is 32.20 and the median is 14.45 — a large gap indicating a right-skewed (positively skewed) distribution.
# * Fare values range from 0 (free tickets) to over 512, showing a wide spread and presence of outliers or high-paying passengers.
# * The high standard deviation (49.69) also supports the presence of large variability in fare prices.

# %%
titanic_df[["Age", "Fare"]].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
titanic_df[["Age", "Fare"]].max()
# Out:
# Age      80.0000
# Fare    512.3292
# dtype: float64

# %%
titanic_df.value_counts("Survived", normalize = True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
titanic_df.Embarked.value_counts(dropna = False)
# Out:
# Embarked
# S      644
# C      168
# Q       77
# NaN      2
# Name: count, dtype: int64

# %%
titanic_df[titanic_df.Sex == "female"].value_counts(
    "Survived"
)
# Out:
# Survived
# 1    233
# 0     81
# Name: count, dtype: int64

# %%
titanic_df.value_counts(["Embarked","Survived"])
# Out:
# Embarked  Survived
# S         0           427
#           1           217
# C         1            93
#           0            75
# Q         0            47
#           1            30
# Name: count, dtype: int64

# %%
# Embarked form S, gender Male , Survival rate ?

titanic_df[
    (titanic_df.Embarked == "S") & (titanic_df.Sex == "male")
].value_counts("Survived")
# Out:
# Survived
# 0    364
# 1     77
# Name: count, dtype: int64

# %%
pd.crosstab(
    titanic_df.Sex,
    titanic_df.Survived,
    margins = True,
    margins_name = "All"
)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
pd.crosstab(
    index = [titanic_df.Embarked, titanic_df.Pclass],
    columns = [titanic_df.Sex, titanic_df.Survived],
    margins=True
)
# Out:
# Sex             female      male       All
# Survived             0    1    0    1
# Embarked Pclass
# C        1           1   42   25   17   85
#          2           0    7    8    2   17
#          3           8   15   33   10   66
# Q        1           0    1    1    0    2
#          2           0    2    1    0    3
#          3           9   24   36    3   72
# S        1           2   46   51   28  127
#          2           6   61   82   15  164
#          3          55   33  231   34  353
# All                 81  231  468  109  889

# %%
# Get Uniques values
unique_values = titanic_df.Embarked.unique()
unique_values
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
# sum() , prod(), cumsum(), var(), std(), mean(), mode(), quantile()
titanic_df.Age.quantile(q = 0.25)
# Out:
# np.float64(20.125)

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
group_by_gender = titanic_df.groupby(by = "Sex")

# %%
group_by_gender.Fare.sum()
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
group_by_gender.value_counts(["Survived"])
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
res = group_by_gender.Age.mean()
res
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
group_by_gender[["Fare", "Age", "Survived"]].sum()
# Out:
#               Fare       Age  Survived
# Sex
# female  13966.6628   7286.00       233
# male    14727.2865  13919.17       109

# %%
group_by_two = titanic_df.groupby(by = ["Embarked", "Survived"])

# %%
group_by_two[["Age","Fare"]].mean()
# Out:
#                          Age       Fare
# Embarked Survived
# C        0         33.666667  35.443335
#          1         28.973671  79.720926
# Q        0         30.325000  13.335904
#          1         22.500000  13.182227
# S        0         30.203966  20.743987
#          1         28.113184  39.547081

# %%
# Correlation and Covariance

# %%
titanic_df[["Age","Fare","SibSp"]].cov()
# Out:
#               Age         Fare     SibSp
# Age    211.019125    73.849030 -4.163334
# Fare    73.849030  2469.436846  8.748734
# SibSp   -4.163334     8.748734  1.216043

# %%
titanic_df[["Age","Fare"]].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sampled = titanic_df.sample(frac=0.25)
sampled
# Out:
#      PassengerId  Survived  Pclass  \
# 366          367         1       1
# 285          286         0       3
# 355          356         0       3
# 386          387         0       3
# 197          198         0       3
# ..           ...       ...     ...
# 813          814         0       3
# 694          695         0       1
# 468          469         0       3
# 160          161         0       3
# 349          350         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 285                               Stankovic, Mr. Ivan    male  33.0      0
# 355                       Vanden Steen, Mr. Leo Peter    male  28.0      0
# 386                   Goodwin, Master. Sidney Leonard    male   1.0      5
# 197                  Olsen, Mr. Karl Siegwart Andreas    male  42.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
sampled[["Age","Fare"]].corr()
# Out:
#            Age      Fare
# Age   1.000000 -0.028119
# Fare -0.028119  1.000000
