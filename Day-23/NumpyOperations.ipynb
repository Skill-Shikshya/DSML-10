# %%
import numpy as np

# %%
a = np.random.randint(1,6, (2,3))
b = np.random.randint(6,10, (3,3))
c = np.random.randint(1,9, (3,3))

# %%
b,c
# Out:
# (array([[7, 9, 8],
#         [6, 9, 9],
#         [7, 8, 9]]),
#  array([[7, 6, 1],
#         [3, 3, 6],
#         [8, 4, 8]]))

# %% [markdown]
# ## 1. Elementwise Operations

# %% [markdown]
# ### Arithmetic Operations

# %%
# b + c
np.add(b,c)
# Out:
# array([[14, 15,  9],
#        [ 9, 12, 15],
#        [15, 12, 17]])

# %%
# b - c
np.subtract(b,c)
# Out:
# array([[ 0,  3,  7],
#        [ 3,  6,  3],
#        [-1,  4,  1]])

# %%
# b * c
np.multiply(b,c)
# Out:
# array([[49, 54,  8],
#        [18, 27, 54],
#        [56, 32, 72]])

# %%
# b % c
np.mod(b,c)
# Out:
# array([[0, 3, 0],
#        [0, 0, 3],
#        [7, 0, 1]])

# %%
# a ** 2
np.pow(b, 2)
# Out:
# array([[49, 81, 64],
#        [36, 81, 81],
#        [49, 64, 81]])

# %% [markdown]
# ### Trignometric

# %%
np.sin(a)
# Out:
# array([[ 0.84147098,  0.90929743, -0.95892427],
#        [-0.95892427, -0.95892427, -0.7568025 ]])

# %%
cot = 1 /np.tan(b)
cot
# Out:
# array([[ 1.14751542, -2.21084541, -0.14706506],
#        [-3.436353  , -2.21084541, -2.21084541],
#        [ 1.14751542, -0.14706506, -2.21084541]])

# %% [markdown]
# ### Rounding operations

# %%
np.around(cot, 2)
# Out:
# array([[ 1.15, -2.21, -0.15],
#        [-3.44, -2.21, -2.21],
#        [ 1.15, -0.15, -2.21]])

# %%
np.floor(cot)
# Out:
# array([[ 1., -3., -1.],
#        [-4., -3., -3.],
#        [ 1., -1., -3.]])

# %%
np.ceil(cot)
# Out:
# array([[ 2., -2., -0.],
#        [-3., -2., -2.],
#        [ 2., -0., -2.]])

# %% [markdown]
# ## 2. Matrix Operations

# %%
a = np.random.randint(1,50, (20,30))
b = np.random.randint(6,100, (3,3))

# %%
# MAtrix Multiplication

# a @ b

# np.dot(a,b)

res = a.dot(b)

# %%
res.shape
# Out:
# (20, 30)

# %%
# Inverse of a matrix

deter = np.linalg.det(b)
inv = np.linalg.inv(b)

# %%
inv
# Out:
# array([[-0.00149295,  0.0447332 , -0.03610727],
#        [-0.0069671 , -0.12457838,  0.16483273],
#        [ 0.02576721,  0.07978988, -0.11755599]])

# %%
# Prove A * A^-1 = I
np.dot(b, inv).round()
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
